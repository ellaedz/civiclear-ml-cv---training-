# %% [markdown]
# # CIVICLEAR CV Training — Fixed Nested Dataset
# Run these cells in Google Colab with GPU.

# %%
# !pip install -q ultralytics pyyaml pandas

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !nvidia-smi

# %% [markdown]
# ## Count dataset first
# This checks whether nested folders like Barricade.coco, traffic cone.coco, Utility Poles.coco are being seen.

# %%
# !python count_dataset.py

# %% [markdown]
# ## Prepare merged YOLO dataset

# %%
# !python prepare_nested_detection_dataset.py --reset --make-valid-if-missing

# %% [markdown]
# ## Train YOLO

# %%
# !python train.py --epochs 50 --imgsz 640 --batch 16

# %% [markdown]
# ## Test and save predictions

# %%
# !python test_model.py
